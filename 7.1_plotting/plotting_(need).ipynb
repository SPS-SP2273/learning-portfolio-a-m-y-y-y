# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
import numpy as np
import random
from matplotlib import pyplot as plt

# %%
# some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# start plotting
plt.plot(x, y_1, label='Y values', color='red', linestyle='dashed')
# ^uses list x for values x, list y_1 for values of y, line label "Y values"

# add another plot command to the graph
plt.plot(x, y_2, label='Y2 values', color='blue')

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)             # transparency of grid
plt.legend(loc='upper left')    # location of legend

# add yet another plot but with error bars
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75
plt.errorbar(x, y_3,
            xerr=x_error, yerr=y_error,
            label="Y3 with errors",
            color="green")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# y = mx + c but we hard code it

m, c = 3, 1
x_values1 = [x for x in range(10)]
y_values1 = [m*x_value + c + random.random() for x_value in x_values1]
plt.plot(x_values1,y_values1)

m, c = 5, 1
x_values2 = [x for x in range(10)]
y_values2 = [m*x_value + c + random.random() for x_value in x_values2]
plt.plot(x_values2,y_values2)

m, c = 7, 1
x_values3 = [x for x in range(10)]
y_values3 = [m*x_value + c + random.random() for x_value in x_values3]
plt.plot(x_values3,y_values3)

plt.plot(x_values1, y_values1)
plt.plot(x_values2, y_values2)
plt.plot(x_values3, y_values3)

# %%
def my_line(m,c):
    x_values = [x for x in range(10)]
    y_values = [m*x_value + c + 5*np.random.random() for x_value in x_values]
    return x_values, y_values

for m in range(5):
    x,y = my_line(m,9)
    plt.plot(x,y)

# %%
def write_data(m,c):
    x_values = np.linspace(0,10,100)
    y_values = n + x_values + c +5*np.random.random()
    np.savetext(f"hahaha_{m=}_{c=}.txt", (x_values, y_values))

# %%
time = np.arange(10)
y2=time**2
y3=time**3

# use colorbrewer2.org to find suitable colours
plt.plot(time, y2, label="$y^2$", linestyle = "--", color = "#1b9e77")
plt.plot(time, y3, label="$y^3$", color = "#7570b3")
#plt.scatter(time,y)
plt.xlabel("time (s)")
plt.ylabel("Hahaha (ha)")
plt.title("My First Plot")
plt.legend(loc='upper left')
plt.grid(alpha=.25)

# %% [markdown]
# ### Things to note

# %%
# abbrevations:
# color: c
# linestyle: ls
# linewidth: lw
plt.plot(x, y, color='red', linestyle='dashed', linewidth=2)
plt.show()
plt.plot(x, y, c='red', ls='dashed', lw=2)

# %%
# plotting functions usually have default values for the styling parameters
# we can just use plt.plot(x, y_1, y_2)
# the order of how we specify the keyword arguments doesn't matter

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# refer to first section

# %% [markdown]
# # 2 Better with NumPy

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# see in the next step why numpy is better

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
        color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
        color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
# 2 y-axes and fewer points

x = np.array([0, 1, 2, 3, 4, 5, 6])
# fix the issue with having too few points, replace the line above with the line below
# x = np.linspace(0, 6, 100)

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                # For y-axis 1

plt.twinx()                                                 # This creates a new y-axis 
                                                            # for the plots that comes after

plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                               # For y-axis 2

# %%
plt.style.use("default")

# plt.xkcd()
time=np.linspace(0,10)
y2 = time**2
sin_t = np.sin(time)

plt.plot(time, y2, label="$y^2$", c="orange")
plt.ylabel("$y^2$", rotation=0)
plt.legend()

another_y = plt.twinx() # create a new y-axis
plt.plot(time, sin_t, label=r"$\sin x$")
plt.ylabel(r"$\sin x$", rotation=0)

# plt.scatter(time, y)
plt.xlabel("time (s)")
plt.title("My First Plot")
plt.legend()
plt.grid(alpha=.25)
plt.savefig("hahha.png", dpi=300)

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
        color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
        label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)
# file saved in the same directory (folder) as the one in my notebook
# or we can specify the path in more detail (below is for Windows)
# plt.savefig('<PATH>/simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %%
# download earth temp data?????
data = np.loadtxt('Complete_TAVG_daily.txt',
                    skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
url = https://berkeleyearth.org/

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
